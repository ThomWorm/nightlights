# %%
PATHS = {
"states_shp": "data/shapefiles/states/tl_2024_us_state.shp",
"counties_shp": "data/shapefiles/counties/tl_2024_us_county.shp",
"radiance_newer": "data/VIIRS/2021/SVDNB_npp_20211101-20211130_75N180W_vcmcfg_v10_c202112060900.avg_rade9h.tif",
"imperv_newer": "data/NLCD/Annual_NLCD_FctImp_2021_CU_C1V0.tif",
"imperv_older": "data/NLCD/Annual_NLCD_FctImp_2019_CU_C1V0.tif",

"output": "data/processed_states"
}

# %%
#write paths to a dotenv file
with open(".env", "w") as f:
    for key, value in PATHS.items():
        f.write(f"{key.upper()}={value}\n")
